# %%
! pwd
# Out:
# /Users/trixiesouthwood/Downloads/research/moose-wolves-sheaf/two-way

# %% [markdown]
# ### Netlist Sheaf

# %%
import numpy as np
import pysheaf as ps
import scipy
import scipy.linalg
import matplotlib.pyplot as plt
import math

class NetlistSheaf(ps.Sheaf):
    def __init__(self, parts, nets, **kwargs):
        '''
Construct a netlist sheaf using a dictionary of `parts` and `nets`.  
Additional optional arguments accepted as `**kwargs`, so that these can be used as parameters as the sheaf is being built.  

> [!CAUTION]
> This function uses `eval()` to unpack and build Python expressions from strings.  You have been warned; sanitize your input!

Each part is named, and has fields:
* `data_dimension`, 
* `bounds` (optional), 
* `ports`.

The `ports` field is a dictionary naming each port, and associating a string that defines a function for the corresponding restriction map.  

Example:
```
{ "AND2" : { "data_dimension" : 2,
	     "bounds" : "[(0,1)]*2",
	     "ports" : { "IN1" : "lambda x: x[0]",
		       "IN2" : "lambda x: x[1]",
		       "OUT" : "lambda x: x[0]*x[1]" }},
...}
```

Each net is named, and has fields:
* `data_dimension`,
* `bounds` (optional),
* `value` (optional; NB: parsed with `eval()`),
* `optimize` (optional; anything not integer `0` is `True`; default = `True`),
* `constraint` (optional; 'equality' -> `pysheaf.CellConstraintType.EQUALITY`, 'inequality' -> `pysheaf.CellConstraintType.INEQUALITY`, anything else is `pysheaf.CellConstraintType.NONE`)
* `connections`.
Subsequently, `connections` is a list of dictionaries, each one has a `part` and `port` field, which index into the `parts` dictionary above.

```
Example
{
    "A": {
	"data_dimension" : 1,
	"bounds" : "[(0,1)]",
	"connections" : [
	       { "part" : "AND2",
		 "port" : "IN1"}
	   ]
    },
...}
```

> [!TIP]
> The default behavior is that all parts are optimization cells, and that no nets are optimization cells.
        '''
        
        ps.Sheaf.__init__(self)

        self.mNumpyNormType=2

        # First, build the parts (lower level of poset)
        for k,v in parts.items():
            if isinstance(v['data_dimension'],int):
                ddim = v['data_dimension']
            else:
                ddim = eval(v['data_dimension'])
                
            self.AddCell(k,
                         ps.Cell('part',
                                 dataDimension = ddim))
                
            self.GetCell(k).SetDataAssignment(ps.Assignment('part',np.zeros((ddim,))))
            self.GetCell(k).mOptimizationCell = True

        # Next, build the nets (upper level of poset)
        for k,v in nets.items():
            if isinstance(v['data_dimension'],int):
                ddim = v['data_dimension']
            else:
                ddim = eval(v['data_dimension'])

            self.AddCell(k,
                         ps.Cell('net',
                                 dataDimension = ddim))
            
            try:
                self.GetCell(k).SetDataAssignment(ps.Assignment('net',eval(v['value'])))
            except KeyError:
                self.GetCell(k).SetDataAssignment(ps.Assignment('net',np.zeros((ddim,))))

            try:
                self.GetCell(k).mOptimizationCell = (v['optimize']!=0)
            except KeyError:
                pass

            try:
                if v['constraint'] == 'inequality':
                    self.GetCell(k).mConstraintType = ps.CellConstraintType.INEQUALITY
                elif v['constraint'] == 'equality':
                    self.GetCell(k).mConstraintType = ps.CellConstraintType.EQUALITY
            except KeyError:
                pass

            # Connect each part in this net
            for vp in v['connections']:
                part=vp['part']
                port=vp['port']
                self.AddCoface(part,k,
                               ps.Coface('part','net',
                                         eval(parts[part]['ports'][port])))
        return

# %%
import csv
import json
import sys
import numpy as np
import scipy.linalg
import networkx as nx
import pysheaf as ps
import matplotlib.pyplot as plt
sys.path.append('/Users/trixiesouthwood/Downloads/research/moose-wolves-sheaf/netlist-sheaf/')
import netlist_sheaf
import numpy.random
import numpy.polynomial
from collections import defaultdict

# %%
### Example based upon Figure 4 in
# Thorson et al., "Dynamic structural equation models synthesize ecosystem dynamics constrained by ecological mechanisms", DOI: 10.1111/2041-210X.14289
#
# This model uses the netlist sheaf construction.

import csv
import json
import numpy as np
import scipy.linalg
import pysheaf as ps
import matplotlib.pyplot as plt
import netlist_sheaf
from collections import defaultdict

# Names in the Thorson data disagree with their paper
names_dict={
    "wolves" : "wolves",
    "moose" : "moose"
    }

def lag_fcn(npts,ar,x):
    '''Convenience function for building lag matrices'''
    if ar:
        return scipy.linalg.toeplitz(np.concatenate(([0],x[0:ar],np.zeros((npts-ar-1,)))),np.zeros((npts,)))
    else: # Disable autoregression
        return np.eye(npts)

# Load the sheaf structure
parts=json.load(open('/Users/trixiesouthwood/Downloads/research/two_way_parts_copy.json'))
parts
# Out:
# {'wolves-block': {'data_dimension': "kwargs['npts']+2",
#   'ports': {'in': 'lambda x: x[2:]',
#    'crop': "lambda x,ar=kwargs['ar']: x[ar+2:]",
#    'out': 'lambda x: x[0]+x[1]*x[2:]',
#    'pc': 'lambda x: x[1]',
#    'constant': 'lambda x: x[0]'}},
#  'moose-block': {'data_dimension': "kwargs['npts']+2",
#   'ports': {'in': 'lambda x: x[2:]',
#    'crop': "lambda x,ar=kwargs['ar']: x[ar+2:]",
#    'out': 'lambda x: x[0]+x[1]*x[2:]',
#    'pc': 'lambda x: x[1]',
#    'constant': 'lambda x: x[0]'}},
#  'moose-lag': {'data_dimension': "kwargs['npts']+kwargs['ar']",
#   'ports': {'in': "lambda x,npts=kwargs['npts'],ar=kwargs['ar']: x[ar:]",
#    'out': "lambda x,npts=kwargs['npts'],ar=kwargs['ar'],lag_fcn=kwargs['lag_fcn']: np.dot(lag_fcn(npts,ar,x),x[ar:])[ar:]"}},
#  'wolves-lag': {'data_dimension': "kwargs['npts']+kwargs['ar']",
#   'ports': {'in': "lambda x,npts=kwargs['npts'],ar=kwargs['ar']: x[ar:]",
#    'out': "lambda x,npts=kwargs['npts'],ar=kwargs['ar'],lag_fcn=kwargs['lag_fcn']: np.dot(lag_fcn(npts,ar,x),x[ar:])[ar:]"}}}

# %%
nets=json.load(open('/Users/trixiesouthwood/Downloads/research/two_way_nets_copy.json'))
nets
# Out:
# {'moose': {'data_dimension': "kwargs['npts']",
#   'optimize': 1,
#   'connections': [{'part': 'wolves-block', 'port': 'in'},
#    {'part': 'moose-lag', 'port': 'in'},
#    {'part': 'moose-block', 'port': 'out'}]},
#  'wolves': {'data_dimension': "kwargs['npts']",
#   'optimize': 1,
#   'connections': [{'part': 'wolves-block', 'port': 'out'},
#    {'part': 'moose-block', 'port': 'in'},
#    {'part': 'wolves-lag', 'port': 'in'}]},
#  'moose-pc': {'data_dimension': 1,
#   'value': '0.6',
#   'optimize': 1,
#   'constraint': 'equality',
#   'connections': [{'part': 'wolves-block', 'port': 'pc'}]},
#  'wolves-pc': {'data_dimension': 1,
#   'value': '0.6',
#   'optimize': 1,
#   'constraint': 'equality',
#   'connections': [{'part': 'moose-block', 'port': 'pc'}]},
#  'moose-lagvar': {'data_dimension': "kwargs['npts']-kwargs['ar']",
#   'optimize': 1,
#   'connections': [{'part': 'wolves-block', 'port': 'crop'},
#    {'part': 'moose-lag', 'port': 'out'}]},
#  'wolves-lagvar': {'data_dimension': "kwargs['npts']-kwargs['ar']",
#   'optimize': 1,
#   'connections': [{'part': 'moose-block', 'port': 'crop'},
#    {'part': 'wolves-lag', 'port': 'out'}]}}

# %%
from enum import Enum

class CellConstraintType(Enum):
    EQUALITY = 0
    INEQUALITY = 1

ps.CellConstraintType = CellConstraintType



startyear = 1959
npts = 61
ar = 0
shf = netlist_sheaf.NetlistSheaf(parts,nets,npts=npts,ar=ar,lag_fcn=lag_fcn)

pos=nx.layout.spring_layout(shf)
nx.draw_networkx_labels(shf,pos)
nx.draw_networkx_edges(shf,pos)
plt.show()

# Load the data; adding in new cells to house the known values
measurements = defaultdict(list)
with open('/Users/trixiesouthwood/Downloads/research/moose-wolves-sheaf/log_isle_royal_data.csv') as fp:
    reader = csv.DictReader(fp, delimiter = ',')
    idx = 0
    for row in reader:
        for data_name,sheaf_name in names_dict.items():
            if row[data_name] != 'NA':
                year = startyear+idx
                datum = str(year) + "-" + sheaf_name
                value = float(row[data_name])

                measurements[sheaf_name].append((year,value))
                
                shf.AddCell(datum, ps.Cell('datum',dataDimension=1))
                shf.GetCell(datum).SetDataAssignment(ps.Assignment('datum', np.array([value])))
                shf.AddCoface(sheaf_name,datum,
                              ps.Coface('net','datum', lambda x,idx=idx : x[idx] ))
        
        idx = idx + 1

# Load in DSEM predictions
dsem_values = defaultdict(list)
with open('/Users/trixiesouthwood/Downloads/research/moose-wolves-sheaf/wolf_moose_dsem.csv') as fp:   
    reader = csv.DictReader(fp, delimiter = ',')
    idx = 0
    for row in reader:
        for data_name,sheaf_name in names_dict.items():
            if row[data_name] != 'NA':
                year = startyear+idx
                datum = str(year) + "-" + sheaf_name
                value = float(row[data_name])

                dsem_values[sheaf_name].append((year,value))        
        idx = idx + 1
    # functions

# %%
star_consistency = []
total_CR = []

for c in shf.GetCellIndexList():
    shf.MaximallyExtendCell(c)

print('===')
print("Consistency radius before optimization: {}".format(shf.ComputeConsistencyRadius()))

print('Optimizing...')
shf.FuseAssignment()

print("Consistency radius after optimization: {}".format(shf.ComputeConsistencyRadius()))

print('===')
print("Path coefficients:") 
print('---')

for c in shf.GetCellIndexList():
    if "-pc" in c:
        print("{} : {}".format(c,shf.GetCell(c).mDataAssignment.mValue))

print('===')
print("Offsets:")
print('---')

for c in shf.GetCellIndexList():
    if c == 'moose-block':
        print("{} : {}".format(c,shf.GetCell(c).mDataAssignment.mValue[0:2]))
    elif "-block" in c:
        print("{} : {}".format(c,shf.GetCell(c).mDataAssignment.mValue[0]))

print('===')
print("Autoregressive cofficients:")
print('---')

for data_name,sheaf_name in names_dict.items():
    try:
        print("{} : {}".format(sheaf_name,shf.GetCell(sheaf_name + "-lag").mDataAssignment.mValue[0:ar]))
    except KeyError:
        pass


print('')
print('==========')
print('All stalks')
print('---')
for c in shf.GetCellIndexList():
    print("{} : Star local consistency radius: {}".format(c,shf.ComputeStarLocalConsistencyRadius(c)))
    print("- -")
    print("{} : {}".format(c,shf.GetCell(c).mDataAssignment.mValue))

star_consistency.append(shf.ComputeStarLocalConsistencyRadius(c))
total_CR.append
        
years=[startyear + year for year in range(npts)]

fig = plt.figure()
axes = fig.subplots(2,2, sharex='all')
row = 0
col = 0
for data_name,sheaf_name in names_dict.items():
    axes[row,col].plot([x for x,y in dsem_values[sheaf_name]],[y for x,y in dsem_values[sheaf_name]],'k:',label='DSEM')
    axes[row,col].plot(years,shf.GetCell(sheaf_name).mDataAssignment.mValue,'b',label='Sheaf')
    axes[row,col].plot([x for x,y in measurements[sheaf_name]],[y for x,y in measurements[sheaf_name]],'*',label='Measurement')
    axes[row,col].set_title(sheaf_name)
    axes[row,col].legend()

    row += 1
    if row > 2:
        row = 0
        col += 1

plt.show()
# Out:
# ===
# Consistency radius before optimization: 4.925548505414726
# Optimizing...
# Consistency radius after optimization: 4.925548443138828
# ===
# Path coefficients:
# ---
# moose-pc : [-2.98665589]
# wolves-pc : [-0.29863544]
# ===
# Offsets:
# ---
# wolves-block : 23.33038848671104
# moose-block : [ 7.70453975 -0.29749349]
# ===
# Autoregressive cofficients:
# ---
# wolves : []
# moose : []
#
# ==========
# All stalks
# ---
# wolves-block : Star local consistency radius: 3.580606973477463
# - -
# wolves-block : [23.33038849 -2.98615383  6.7513028   6.72822852  6.729851    6.71795814
#   6.76276686  6.68908509  6.6695922   6.69628001  6.76243031  6.77396289
#   6.87348118  6.85689718  6.83941978  6.80337357  6.78815856  6.71097258
#   6.62153235  6.59351529  6.65689072  6.59529732  6.57552177  6.52117654
#   6.67050653  6.89898375  6.75827996  6.75786644  6.7895373   6.82218619
#   6.8920098   6.98495917  6.99838286  6.93684842  7.0176843   7.03172843
#   7.01347627  6.94734299  6.97084451  6.89009849  6.75454951  6.91812969
#   6.75365222  6.71348092  6.84854295  6.87962555  6.82413803  6.67783087
#   6.63111461  6.61066136  6.69954434  6.73088141  6.69554973  6.76056322
#   6.81283787  7.02613627  7.09052587  7.06365016  7.41039551  7.53523117
#   7.55868417  7.54928821  6.98701622]
# moose-block : Star local consistency radius: 3.494410943952684
# - -
# moose-block : [ 7.70453975 -0.29749349  3.12613597  3.20296148  3.19943859  3.23745276
#   3.10069287  3.33403147  3.3969661   3.31804132  3.12680203  3.10137715
#   2.81175923  2.86378571  2.93039081  3.0469238   3.09266527  3.33182992
#   3.60415284  3.68537437  3.47678014  3.65586924  3.71935993  3.87990675
#   3.41348359  2.70373563  3.14803484  3.15931253  3.06652499  2.96878934
#   2.75442019  2.47238501  2.44182555  2.63773147  2.39919129  2.36783562
#   2.4293549   2.64660269  2.57902517  2.84291785  3.16686387  2.66148333
#   3.17953991  3.30876622  2.89621307  2.79805001  2.95087715  3.38771361
#   3.50065069  3.5461686   3.25437676  3.2090942   3.29970798  3.09221028
#   2.93104806  2.30462758  2.13018868  2.22079959  1.15996181  0.77456763
#   0.72532494  0.74342841  2.52606103]
# moose-lag : Star local consistency radius: 2.2224815159381883
# - -
# moose-lag : [6.49608628 6.51197377 6.52030122 6.52173193 6.55795612 6.54711573
#  6.55054265 6.5853914  6.69604421 6.75738075 6.91442824 6.90926612
#  6.96974696 6.98132776 6.96196988 6.92249641 6.85283386 6.80594292
#  6.76767422 6.67660499 6.6755292  6.60536375 6.65635288 6.76631949
#  6.73848941 6.79938727 6.84166087 6.87727372 6.92517033 7.00206024
#  7.07488459 7.07135138 7.17832811 7.25392229 7.27376366 7.31207318
#  7.34914779 7.38201102 6.78159533 6.86885143 6.83771746 6.83848652
#  6.94380755 6.94761655 6.81226224 6.64730901 6.44506128 6.3348658
#  6.28815746 6.59160671 6.46348047 6.47055372 6.49884036 6.80082473
#  6.97431362 7.00315242 7.25284505 7.32906546 7.45320218 7.40431939
#  7.34159903]
# wolves-lag : Star local consistency radius: 0.6894576441429452
# - -
# wolves-lag : [3.05816339 3.14473463 3.14295994 3.18423119 3.04599013 3.29422216
#  3.36275411 3.28644644 3.10791876 3.09485661 2.82291207 2.87754407
#  2.96399863 3.09192545 3.13640339 3.3839902  3.65942361 3.73559536
#  3.50180178 3.67223683 3.74020883 3.89573158 3.40662631 2.67051317
#  3.14140292 3.16882034 3.07896968 2.98256088 2.76393325 2.47968609
#  2.46469484 2.67430534 2.44422626 2.42892622 2.49980558 2.74304329
#  2.67941753 2.97100105 3.17241818 2.65002001 3.19953545 3.33854571
#  2.92118111 2.81628554 2.94745352 3.37649118 3.4482701  3.47056238
#  3.14512241 3.17098878 3.2362407  3.0156619  2.84928555 2.24989225
#  2.10495666 2.20899626 1.12990913 0.7352859  0.71128636 0.7200201
#  2.62058876]
# moose : Star local consistency radius: 1.6378503500046335
# - -
# moose : [6.57803335 6.58247676 6.5888245  6.58661264 6.62377249 6.59559262
#  6.59278776 6.62434541 6.7190776  6.76432861 6.90070871 6.89246481
#  6.92960723 6.9274153  6.9098002  6.86085469 6.78798274 6.74779065
#  6.73897145 6.65867974 6.65266682 6.58879315 6.66589796 6.80572062
#  6.7470944  6.78910172 6.82714813 6.86072369 6.91347741 6.99228753
#  7.04643956 7.02671751 7.12292866 7.17923999 7.18755446 7.19597919
#  7.22800024 7.22834435 6.77580444 6.88175895 6.81443163 6.8035478
#  6.91405963 6.92528986 6.81645992 6.66137578 6.50939295 6.4281837
#  6.42049392 6.63809207 6.53938616 6.56302272 6.59733934 6.86492853
#  7.0022409  7.01512572 7.28307369 7.3716231  7.46521083 7.42876684
#  7.22686631]
# wolves : Star local consistency radius: 0.5196710853676557
# - -
# wolves : [3.08726303 3.16888116 3.16658554 3.20622403 3.06930492 3.30977139
#  3.3757334  3.29856699 3.11525716 3.09736898 2.81836586 2.87157169
#  2.94931349 3.07253405 3.11648473 3.35981328 3.63309    3.71046886
#  3.48813275 3.66165205 3.72740019 3.88421582 3.40750467 2.68571843
#  3.14301018 3.16375722 3.07276894 2.97623829 2.76039482 2.4775639
#  2.45648085 2.65939773 2.42658007 2.40451812 2.47115291 2.70272534
#  2.63681958 2.91549855 3.16891248 2.65601039 3.18962729 3.32372325
#  2.91035928 2.80867567 2.94872911 3.37943289 3.46873309 3.50075926
#  3.19201186 3.18586197 3.26171553 3.04826056 2.88440474 2.27594234
#  2.11888605 2.21731924 1.1510457  0.7617104  0.72519869 0.73998684
#  2.5806932 ]
# moose-pc : Star local consistency radius: 0.0
# - -
# moose-pc : [-2.98665589]
# wolves-pc : Star local consistency radius: 0.0
# - -
# wolves-pc : [-0.29863544]
# moose-lagvar : Star local consistency radius: 0.0
# - -
# moose-lagvar : [6.58447625 6.54627343 6.68247382 6.63939868 6.65165079 6.60527987
#  6.62008965 6.66211144 6.74525429 6.76088704 6.90580288 6.86151625
#  6.88867993 6.82502952 6.81155663 6.83759042 6.69392821 6.65011091
#  6.75375273 6.61940945 6.61865791 6.54631183 6.65834825 6.89441668
#  6.74350508 6.78273619 6.82269769 6.84518795 6.91264504 6.99406571
#  7.04576196 6.98323102 7.12075432 7.20560273 7.09758668 7.14567489
#  7.19449551 7.007402   6.76183985 6.90501294 6.77304123 6.80695748
#  6.88933729 6.89842794 6.81495814 6.66355091 6.50319572 6.48181256
#  6.42235595 6.65094305 6.58938361 6.63974793 6.52041596 7.00747532
#  7.06526771 7.0539722  7.33498127 7.46812078 7.53249199 7.44870537
#  7.29292382]
# wolves-lagvar : Star local consistency radius: 0.0
# - -
# wolves-lagvar : [3.12372842 3.17569438 3.17998096 3.23377794 3.09839978 3.32883374
#  3.38906608 3.3121595  3.12209092 3.09777624 2.81417305 2.86781926
#  2.9333062  3.06951356 3.12285672 3.37966305 3.65736578 3.72500219
#  3.48478633 3.65991439 3.72997076 3.88018249 3.40667839 2.67583213
#  3.1418102  3.16080974 3.06983218 2.97152906 2.75886537 2.47650524
#  2.44258933 2.66502224 2.40371603 2.3835116  2.49518857 2.73425683
#  2.6447465  2.95696349 3.16740983 2.66126789 3.18645439 3.32247963
#  2.89670361 2.80760139 2.94912563 3.37830393 3.49932441 3.50954708
#  3.24009071 3.18471472 3.29714212 3.05215929 2.860557   2.26481944
#  2.11311409 2.22013713 1.15857026 0.76870616 0.72206686 0.74155132
#  2.54202951]
# 1959-wolves : Star local consistency radius: 0.0
# - -
# 1959-wolves : [2.99573227]
# 1959-moose : Star local consistency radius: 0.0
# - -
# 1959-moose : [6.28785856]
# 1960-wolves : Star local consistency radius: 0.0
# - -
# 1960-wolves : [3.09104245]
# 1960-moose : Star local consistency radius: 0.0
# - -
# 1960-moose : [6.33505425]
# 1961-wolves : Star local consistency radius: 0.0
# - -
# 1961-wolves : [3.09104245]
# 1961-moose : Star local consistency radius: 0.0
# - -
# 1961-moose : [6.34913899]
# 1962-wolves : Star local consistency radius: 0.0
# - -
# 1962-wolves : [3.13549422]
# 1962-moose : Star local consistency radius: 0.0
# - -
# 1962-moose : [6.36130248]
# 1963-wolves : Star local consistency radius: 0.0
# - -
# 1963-wolves : [2.99573227]
# 1963-moose : Star local consistency radius: 0.0
# - -
# 1963-moose : [6.39024067]
# 1964-wolves : Star local consistency radius: 0.0
# - -
# 1964-wolves : [3.25809654]
# 1964-moose : Star local consistency radius: 0.0
# - -
# 1964-moose : [6.42971948]
# 1965-wolves : Star local consistency radius: 0.0
# - -
# 1965-wolves : [3.33220451]
# 1965-moose : Star local consistency radius: 0.0
# - -
# 1965-moose : [6.45204895]
# 1966-wolves : Star local consistency radius: 0.0
# - -
# 1966-wolves : [3.25809654]
# 1966-moose : Star local consistency radius: 0.0
# - -
# 1966-moose : [6.49375384]
# 1967-wolves : Star local consistency radius: 0.0
# - -
# 1967-wolves : [3.09104245]
# 1967-moose : Star local consistency radius: 0.0
# - -
# 1967-moose : [6.64118217]
# 1968-wolves : Star local consistency radius: 0.0
# - -
# 1968-wolves : [3.09104245]
# 1968-moose : Star local consistency radius: 0.0
# - -
# 1968-moose : [6.74288064]
# 1969-wolves : Star local consistency radius: 0.0
# - -
# 1969-wolves : [2.83321334]
# 1969-moose : Star local consistency radius: 0.0
# - -
# 1969-moose : [6.94793707]
# 1970-wolves : Star local consistency radius: 0.0
# - -
# 1970-wolves : [2.89037176]
# 1970-moose : Star local consistency radius: 0.0
# - -
# 1970-moose : [6.95177216]
# 1971-wolves : Star local consistency radius: 0.0
# - -
# 1971-wolves : [2.99573227]
# 1971-moose : Star local consistency radius: 0.0
# - -
# 1971-moose : [7.07580886]
# 1972-wolves : Star local consistency radius: 0.0
# - -
# 1972-wolves : [3.13549422]
# 1972-moose : Star local consistency radius: 0.0
# - -
# 1972-moose : [7.12528309]
# 1973-wolves : Star local consistency radius: 0.0
# - -
# 1973-wolves : [3.17805383]
# 1973-moose : Star local consistency radius: 0.0
# - -
# 1973-moose : [7.10249936]
# 1974-wolves : Star local consistency radius: 0.0
# - -
# 1974-wolves : [3.4339872]
# 1974-moose : Star local consistency radius: 0.0
# - -
# 1974-moose : [7.09257372]
# 1975-wolves : Star local consistency radius: 0.0
# - -
# 1975-wolves : [3.71357207]
# 1975-moose : Star local consistency radius: 0.0
# - -
# 1975-moose : [7.03790596]
# 1976-wolves : Star local consistency radius: 0.0
# - -
# 1976-wolves : [3.78418963]
# 1976-moose : Star local consistency radius: 0.0
# - -
# 1976-moose : [6.97541393]
# 1977-wolves : Star local consistency radius: 0.0
# - -
# 1977-wolves : [3.52636052]
# 1977-moose : Star local consistency radius: 0.0
# - -
# 1977-moose : [6.8554088]
# 1978-wolves : Star local consistency radius: 0.0
# - -
# 1978-wolves : [3.68887945]
# 1978-moose : Star local consistency radius: 0.0
# - -
# 1978-moose : [6.73933663]
# 1979-wolves : Star local consistency radius: 0.0
# - -
# 1979-wolves : [3.76120012]
# 1979-moose : Star local consistency radius: 0.0
# - -
# 1979-moose : [6.75343792]
# 1980-wolves : Star local consistency radius: 0.0
# - -
# 1980-wolves : [3.91202301]
# 1980-moose : Star local consistency radius: 0.0
# - -
# 1980-moose : [6.66949809]
# 1981-wolves : Star local consistency radius: 0.0
# - -
# 1981-wolves : [3.40119738]
# 1981-moose : Star local consistency radius: 0.0
# - -
# 1981-moose : [6.6424868]
# 1982-wolves : Star local consistency radius: 0.0
# - -
# 1982-wolves : [2.63905733]
# 1982-moose : Star local consistency radius: 0.0
# - -
# 1982-moose : [6.65929392]
# 1983-wolves : Star local consistency radius: 0.0
# - -
# 1983-wolves : [3.13549422]
# 1983-moose : Star local consistency radius: 0.0
# - -
# 1983-moose : [6.7214257]
# 1984-wolves : Star local consistency radius: 0.0
# - -
# 1984-wolves : [3.17805383]
# 1984-moose : Star local consistency radius: 0.0
# - -
# 1984-moose : [6.83195357]
# 1985-wolves : Star local consistency radius: 0.0
# - -
# 1985-wolves : [3.09104245]
# 1985-moose : Star local consistency radius: 0.0
# - -
# 1985-moose : [6.88346259]
# 1986-wolves : Star local consistency radius: 0.0
# - -
# 1986-wolves : [2.99573227]
# 1986-moose : Star local consistency radius: 0.0
# - -
# 1986-moose : [6.92165818]
# 1987-wolves : Star local consistency radius: 0.0
# - -
# 1987-wolves : [2.77258872]
# 1987-moose : Star local consistency radius: 0.0
# - -
# 1987-moose : [6.95272864]
# 1988-wolves : Star local consistency radius: 0.0
# - -
# 1988-wolves : [2.48490665]
# 1988-moose : Star local consistency radius: 0.0
# - -
# 1988-moose : [7.01750614]
# 1989-wolves : Star local consistency radius: 0.0
# - -
# 1989-wolves : [2.48490665]
# 1989-moose : Star local consistency radius: 0.0
# - -
# 1989-moose : [7.138867]
# 1990-wolves : Star local consistency radius: 0.0
# - -
# 1990-wolves : [2.7080502]
# 1990-moose : Star local consistency radius: 0.0
# - -
# 1990-moose : [7.18159194]
# 1991-wolves : Star local consistency radius: 0.0
# - -
# 1991-wolves : [2.48490665]
# 1991-moose : Star local consistency radius: 0.0
# - -
# 1991-moose : [7.31055016]
# 1992-wolves : Star local consistency radius: 0.0
# - -
# 1992-wolves : [2.48490665]
# 1992-moose : Star local consistency radius: 0.0
# - -
# 1992-moose : [7.43661727]
# 1993-wolves : Star local consistency radius: 0.0
# - -
# 1993-wolves : [2.56494936]
# 1993-moose : Star local consistency radius: 0.0
# - -
# 1993-moose : [7.48661331]
# 1994-wolves : Star local consistency radius: 0.0
# - -
# 1994-wolves : [2.83321334]
# 1994-moose : Star local consistency radius: 0.0
# - -
# 1994-moose : [7.60936654]
# 1995-wolves : Star local consistency radius: 0.0
# - -
# 1995-wolves : [2.77258872]
# 1995-moose : Star local consistency radius: 0.0
# - -
# 1995-moose : [7.65775527]
# 1996-wolves : Star local consistency radius: 0.0
# - -
# 1996-wolves : [3.09104245]
# 1996-moose : Star local consistency radius: 0.0
# - -
# 1996-moose : [7.78239034]
# 1997-wolves : Star local consistency radius: 0.0
# - -
# 1997-wolves : [3.17805383]
# 1997-moose : Star local consistency radius: 0.0
# - -
# 1997-moose : [6.80239476]
# 1998-wolves : Star local consistency radius: 0.0
# - -
# 1998-wolves : [2.63905733]
# 1998-moose : Star local consistency radius: 0.0
# - -
# 1998-moose : [6.82979374]
# 1999-wolves : Star local consistency radius: 0.0
# - -
# 1999-wolves : [3.21887582]
# 1999-moose : Star local consistency radius: 0.0
# - -
# 1999-moose : [6.90475077]
# 2000-wolves : Star local consistency radius: 0.0
# - -
# 2000-wolves : [3.36729583]
# 2000-moose : Star local consistency radius: 0.0
# - -
# 2000-moose : [6.93828448]
# 2001-wolves : Star local consistency radius: 0.0
# - -
# 2001-wolves : [2.94443898]
# 2001-moose : Star local consistency radius: 0.0
# - -
# 2001-moose : [7.02108396]
# 2002-wolves : Star local consistency radius: 0.0
# - -
# 2002-wolves : [2.83321334]
# 2002-moose : Star local consistency radius: 0.0
# - -
# 2002-moose : [7.00306546]
# 2003-wolves : Star local consistency radius: 0.0
# - -
# 2003-wolves : [2.94443898]
# 2003-moose : Star local consistency radius: 0.0
# - -
# 2003-moose : [6.80239476]
# 2004-wolves : Star local consistency radius: 0.0
# - -
# 2004-wolves : [3.36729583]
# 2004-moose : Star local consistency radius: 0.0
# - -
# 2004-moose : [6.62007321]
# 2005-wolves : Star local consistency radius: 0.0
# - -
# 2005-wolves : [3.40119738]
# 2005-moose : Star local consistency radius: 0.0
# - -
# 2005-moose : [6.29156914]
# 2006-wolves : Star local consistency radius: 0.0
# - -
# 2006-wolves : [3.40119738]
# 2006-moose : Star local consistency radius: 0.0
# - -
# 2006-moose : [6.10924758]
# 2007-wolves : Star local consistency radius: 0.0
# - -
# 2007-wolves : [3.04452244]
# 2007-moose : Star local consistency radius: 0.0
# - -
# 2007-moose : [5.95324333]
# 2008-wolves : Star local consistency radius: 0.0
# - -
# 2008-wolves : [3.13549422]
# 2008-moose : Star local consistency radius: 0.0
# - -
# 2008-moose : [6.47697236]
# 2009-wolves : Star local consistency radius: 0.0
# - -
# 2009-wolves : [3.17805383]
# 2009-moose : Star local consistency radius: 0.0
# - -
# 2009-moose : [6.27287701]
# 2010-wolves : Star local consistency radius: 0.0
# - -
# 2010-wolves : [2.94443898]
# 2010-moose : Star local consistency radius: 0.0
# - -
# 2010-moose : [6.23441073]
# 2011-wolves : Star local consistency radius: 0.0
# - -
# 2011-wolves : [2.77258872]
# 2011-moose : Star local consistency radius: 0.0
# - -
# 2011-moose : [6.2441669]
# 2012-wolves : Star local consistency radius: 0.0
# - -
# 2012-wolves : [2.19722458]
# 2012-moose : Star local consistency radius: 0.0
# - -
# 2012-moose : [6.62007321]
# 2013-wolves : Star local consistency radius: 0.0
# - -
# 2013-wolves : [2.07944154]
# 2013-moose : Star local consistency radius: 0.0
# - -
# 2013-moose : [6.88243747]
# 2014-wolves : Star local consistency radius: 0.0
# - -
# 2014-wolves : [2.19722458]
# 2014-moose : Star local consistency radius: 0.0
# - -
# 2014-moose : [6.95654544]
# 2015-wolves : Star local consistency radius: 0.0
# - -
# 2015-wolves : [1.09861229]
# 2015-moose : Star local consistency radius: 0.0
# - -
# 2015-moose : [7.13089883]
# 2016-wolves : Star local consistency radius: 0.0
# - -
# 2016-wolves : [0.69314718]
# 2016-moose : Star local consistency radius: 0.0
# - -
# 2016-moose : [7.17011954]
# 2017-wolves : Star local consistency radius: 0.0
# - -
# 2017-wolves : [0.69314718]
# 2017-moose : Star local consistency radius: 0.0
# - -
# 2017-moose : [7.37775891]
# 2018-wolves : Star local consistency radius: 0.0
# - -
# 2018-wolves : [0.69314718]
# 2018-moose : Star local consistency radius: 0.0
# - -
# 2018-moose : [7.29641327]
# 2019-wolves : Star local consistency radius: 0.0
# - -
# 2019-wolves : [2.7080502]
# 2019-moose : Star local consistency radius: 0.0
# - -
# 2019-moose : [7.63046126]

# %%
fig = plt.figure()
axes = fig.subplots(2, 1, sharex='all')

for ax, (data_name, sheaf_name) in zip(axes.flat, names_dict.items()):
    ax.plot([x for x,y in dsem_values[sheaf_name]],
            [np.exp(y) for x,y in dsem_values[sheaf_name]],
            'k:', label='DSEM')
    
    ax.plot(years, np.exp(shf.GetCell(sheaf_name).mDataAssignment.mValue), 
            'b', label='Sheaf')
    
    ax.plot([x for x,y in measurements[sheaf_name]],
            [np.exp(y) for x,y in measurements[sheaf_name]],
            '*', label='Measurement')
    
    ax.set_title(sheaf_name)
    ax.legend()

    ax.axvspan(xmin=1980, xmax=1982, color='red', alpha=0.2)
    ax.axvspan(xmin=1996, xmax=1997, color='green', alpha=0.2)
    ax.axvspan(xmin=2003, xmax=2015, color='blue', alpha=0.2)


for ax in axes.flat[len(names_dict):]:
    ax.axis('off')
    
   
plt.tight_layout()
#plt.show()
plt.savefig("Two_way_output.png")
